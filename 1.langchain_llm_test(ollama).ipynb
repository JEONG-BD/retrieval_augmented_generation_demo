# %% [markdown]
# #### 1. pyenv 가상환경 생성 및 LLM 개발 환경 설정

# %%
# %pyenv virtualenv inflearn-llm-application 
# %pyenv virtualenvs 
# %pyenv local inflearn-llm-application 
# %pip list
# %pip install -U langchain-openai python-dotenv openai langchain-ollama
# %pip list

# %%
#pip install --upgrade pip 
#%pip list | grep ollama
# %pip install -U langchain-ollama

# %% [markdown]
# #### 2. Ollama 사용

# %%
from langchain_ollama import ChatOllama

ollama_llm = ChatOllama(
    model="gemma4:latest",
    temperature=0,
    num_predict=512,
    repeat_penalty=1.1,
)

# %% [markdown]
# #### 3. Test

# %%
ai_message = ollama_llm.invoke("오늘 한국의 부산 날씨에 대해서 알려줘")
print(ai_message)
