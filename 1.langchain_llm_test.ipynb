# %% [markdown]
# #### 1. pyenv 가상환경 생성 및 LLM 개발 환경 설정

# %%
# %pyenv virtualenv inflearn-llm-application 
# %pyenv virtualenvs 
# %pyenv local inflearn-llm-application 
# %pip list
# %pip install -U langchain-openai, python-dotenv, openai

# %% [markdown]
# #### 2. env 설정

# %%
from dotenv import load_dotenv
import os 
load_dotenv(dotenv_path='./.env')

# %% [markdown]
# #### 3.1 UPSTAGE_API 사용

# %%
from langchain_openai import ChatOpenAI
upstage_llm = ChatOpenAI(
    model="solar-pro2",
    api_key=os.getenv("UPSTAGE_API_KEY"),
    base_url="https://api.upstage.ai/v1"
)

# %% [markdown]
# #### 3.2 OpenAI 사용

# %%
from langchain_openai import ChatOpenAI

chatopen_llm = ChatOpenAI()

# %% [markdown]
# #### 3.2 Test

# %%
ai_message = upstage_llm.invoke("오늘 한국의 부산 날씨에 대해서 알려줘")
print(ai_message)
